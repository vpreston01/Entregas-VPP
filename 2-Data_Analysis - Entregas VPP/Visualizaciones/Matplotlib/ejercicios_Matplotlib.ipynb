# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import os
os.getcwd()
# Out:
# 'c:\\Users\\vipre\\OneDrive\\Escritorio\\DATA SCIENCE BOOTCAMP\\Mesa Trabajo Bootcamp VPP\\4-Visualización\\1-Matplotlib\\ejercicios'

# %% [markdown]
# 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline

# %% [markdown]
# 3. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
canva = plt.figure(figsize= (4,3))
x = np.linspace(0,5,5)

grafica1 = canva.add_subplot(1,2,1)
m = 3
y=m*x
plt.plot(x,y)
plt.xlim(-1,5)
plt.ylim(-1,15)
plt.tight_layout()

grafica2 = canva.add_subplot(1,2,2)
m = -3
y = m*x -5
plt.plot(x,y)
plt.xlim(0,5)
plt.ylim(-20,-6)
plt.tight_layout()

# %% [markdown]
# 4. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
canva = plt.figure(figsize= (4,3))
x = np.linspace(0,5,5)

grafica1 = canva.add_subplot(1,2,1)
m = 3
y=m*x
plt.plot(x,y)
plt.xlim(0,5)
plt.ylim(-15,15)
plt.tight_layout()

grafica2 = canva.add_subplot(1,2,2)
m = -3
y = m*x-5
plt.plot(x,y)
plt.xlim(0,5)
plt.ylim(-15,15)
plt.tight_layout()

# %% [markdown]
# 5. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
canva = plt.figure(figsize= (4,3))
x = np.linspace(0,5,5)



grafica1 = canva.add_subplot(1,2,1)
m = 3
y=m*x
plt.plot(x,y)
plt.title("Recta sube")
plt.ylabel("eje y")
plt.xticks([0,1,2,3,4,5])
plt.xlabel("eje x")
plt.xlim(0,5)
plt.ylim(-15,15)

grafica2 = canva.add_subplot(1,2,2)
m = -3
y = m*x-5
plt.plot(x,y)
plt.title("Recta baja")
plt.xlabel("eje x")
plt.xticks([0,1,2,3,4,5])
plt.xlim(0,5)
plt.ylim(-15,15)
plt.tight_layout()

# %% [markdown]
# Vamos a pintar lo mismo pero accediendo directamente a los ejes

# %% [markdown]
# 6. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
fig,(ax1,ax2) = plt.subplots(1, 2, figsize=(4, 3))  
x = np.linspace(0, 5, 5)

y1=3*x
ax1.plot(x,y1)
ax1.set_title("Recta sube")
ax1.set_ylabel("eje y")
ax1.set_xlabel("eje x")
ax1.set_xticks([0,1,2,3,4,5])
ax1.set_xlim(0,5)
ax1.set_ylim(-15,15)

y2 = -3 * x - 5
ax2.plot(x,y)
ax2.set_title("Recta baja")
ax2.set_xlabel("eje x")
ax2.set_xlim(0,5)
ax2.set_xticks([0,1,2,3,4,5])
ax2.set_ylim(-15,15)
plt.tight_layout()

# %% [markdown]
# 7. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

plt.bar(x,y)
plt.title("Gráfico de Barras")
plt.xlabel("Coordenas x")
plt.ylabel("Coordenas y")
# Out:
# Text(0, 0.5, 'Coordenas y')

# %% [markdown]
# 8. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
altura = [160,180,175,190,170]
nombres = ["Ana","Luis","Pedro","Sofía","Carmen"]

plt.bar(nombres,altura, color="green")
plt.title("Altura Grupo de Amigos")
plt.xlabel("Personas")
plt.ylabel("Altura")
# Out:
# Text(0, 0.5, 'Altura')

# %% [markdown]
# 9. Basándote en el gráfico anterior, escribe encima de cada barra la altura de cada amigo.
# Pista: usa un bucle que lea cada barra de barplot = plt.bar(x,y)
# bar tiene los métodos get_height(), get_x(), get_width()
# plt.text(x,y,valor, va='bottom')

# %%
barplot = plt.bar(nombres, altura, color='green')
# plt.plot([-0.4], [160], "xr")

# for bar in barplot:
#     yval = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2, yval+1, int(yval))

for x, y  in enumerate(altura):
    plt.text(x-0.2, y+1, y)

# plt.bar(personas, alturas, color='green')
plt.xlabel("Personas")
plt.ylabel("Alturas")
plt.title("Alturas grupo amigos");

# %% [markdown]
# 10. Cambia el tamaño de la figura a (3,5)

# %%
plt.figure(figsize=(3,5))

altura = [160,180,175,190,170]
nombres = ["Ana","Luis","Pedro","Sofía","Carmen"]
for x, y  in enumerate(altura):
    plt.text(x-0.2, y+1, y)

plt.bar(nombres,altura, color="green")
plt.title("Altura Grupo de Amigos")
plt.xlabel("Personas")
plt.ylabel("Altura")
# Out:
# Text(0, 0.5, 'Altura')

# %% [markdown]
# 11. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
#
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
plt.figure(figsize=(3,5))

altura = [160,180,175,190,170]
nombres = ["Ana","Luis","Pedro","Sofía","Carmen"]
for x, y  in enumerate(altura):
    plt.text(x-0.2, y+1, y)

plt.bar(nombres,altura, color="green")
plt.title("Altura Grupo de Amigos")
plt.yticks([])
plt.xlabel("Personas")
plt.ylabel("Altura")
# Out:
# Text(0, 0.5, 'Altura')

# %% [markdown]
# 12. Prueba a hacer el gráfico con las barras en horizontal (no es necesario poner el texto al final de la barra).

# %%
altura = [160,180,175,190,170]
nombres = ["Ana","Luis","Pedro","Sofía","Carmen"]

plt.barh(nombres,altura)
plt.title("Altura Grupo de Amigos")
plt.xlabel("Personas")
plt.ylabel("Altura")
# Out:
# Text(0, 0.5, 'Altura')

# %% [markdown]
# 13. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
fig, ax = plt.subplots()

altura = [160,180,175,190,170]
plt.gca().invert_yaxis()
nombres = ["Ana","Luis","Pedro","Sofía","Carmen"]

ax.barh(nombres,altura)
ax.set_title("Altura Grupo de Amigos")
ax.set_xlabel("Personas")
ax.set_ylabel("Altura")
# Out:
# Text(0, 0.5, 'Altura')

# %% [markdown]
# 14. En el último gráfico, cambia el estilo a 'dark_background'

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
fig, ax = plt.subplots()

altura = [160,180,175,190,170]
plt.gca().invert_yaxis()
nombres = ["Ana","Luis","Pedro","Sofía","Carmen"]

ax.barh(nombres,altura)
ax.set_title("Altura Grupo de Amigos")
ax.set_xlabel("Personas")
ax.set_ylabel("Altura")
# Out:
# Text(0, 0.5, 'Altura')

# %% [markdown]
# 15. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
# Apunte profesor

df = pd.DataFrame({'year': [2015,2016,2017,2018,2019],
                    'sold_items_A': [1000, 3500, 4000, 5500, 7000],
                    "dates":["4th July, 2020", "1970-10-10", "20200707", "13/2/2024", "05-20-2021"]})
df.loc[:,"dates2"] = df.loc[:,"dates"].apply(lambda x: pd.to_datetime(x))
df.loc[:, "dates2"].dt.day_name()
# Out:
# C:\Users\vipre\AppData\Local\Temp\ipykernel_11392\1080252114.py:6: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df.loc[:,"dates2"] = df.loc[:,"dates"].apply(lambda x: pd.to_datetime(x))
# 0    Saturday
# 1    Saturday
# 2     Tuesday
# 3     Tuesday
# 4    Thursday
# Name: dates2, dtype: object

# %%
data = {

    "Year" : [2015,2016,2017,2018,2019],
    "Sold_items_A": [1000,3500,4000,5500,7000]
    
}

df =pd.DataFrame(data)
df
# Out:
#    Year  Sold_items_A
# 0  2015          1000
# 1  2016          3500
# 2  2017          4000
# 3  2018          5500
# 4  2019          7000

# %%
df.dtypes
# Out:
# Year            int64
# Sold_items_A    int64
# dtype: object

# %% [markdown]
# 16. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8-white")
plt.plot(round(df.loc[:,"Year"]),df.loc[:,"Sold_items_A"],color="green",linestyle= "--")
plt.xlabel("Year")
plt.xticks([2015,2016,2017,2018,2019])
plt.legend(["Sold_items_A"])

# %% [markdown]
# 17. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
data = {

    "Year" : ["2015-01-01","2016-01-01","2017-01-01","2018-01-01","2019-01-01"],
    "Sold_items_A": [1000,3500,4000,5500,7000],
    "Sold_items_B" : [2000,3100,5000,4000,6000]
}

df =pd.DataFrame(data)
df
# Out:
#          Year  Sold_items_A  Sold_items_B
# 0  2015-01-01          1000          2000
# 1  2016-01-01          3500          3100
# 2  2017-01-01          4000          5000
# 3  2018-01-01          5500          4000
# 4  2019-01-01          7000          6000

# %%
plt.style.use("seaborn-v0_8-white")
plt.plot(round(df.loc[:,"Year"]),df.loc[:,"Sold_items_A"],color="green",linestyle= "--")
plt.plot(round(df.loc[:,"Year"]),df.loc[:,"Sold_items_B"],color="red",linestyle= "--")
plt.xlabel("Year")
plt.legend("Sold_items_A")
plt.legend("Sold_items_B", loc=4)

# %% [markdown]
# 18. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
plt.scatter(df.loc[:,"Year"],df.loc[:,"Sold_items_A"])
plt.xlabel("Year")
plt.ylabel("Sold_items_A")
# Out:
# Text(0, 0.5, 'Sold_items_A')

# %% [markdown]
# 19. Prueba a cambiar kind a 'pie'

# %%
plt.pie(df.loc[:,"Sold_items_A"])

plt.legend("12345")
plt.ylabel("Sold_items_A")
# Out:
# Text(0, 0.5, 'Sold_items_A')

# %%
colores = ["red","green","blue","yellow","purple"] 

plt.pie(df.loc[:,"Sold_items_A"], colors=colores)

plt.xlabel("Year")
plt.ylabel("Sold_items_A")
# Out:
# Text(0, 0.5, 'Sold_items_A')

# %% [markdown]
# 20. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
data = {

    "Year" : ["2015-01-01","2016-01-01","2017-01-01","2018-01-01","2019-01-01"],
    "Sold_items_A": [1000,3500,4000,5500,7000],
    "Sold_items_B" : [2000,3100,5000,4000,6000]
}

df =pd.DataFrame(data)
df
# Out:
#          Year  Sold_items_A  Sold_items_B
# 0  2015-01-01          1000          2000
# 1  2016-01-01          3500          3100
# 2  2017-01-01          4000          5000
# 3  2018-01-01          5500          4000
# 4  2019-01-01          7000          6000

# %%
plt.pie(df.loc[:,"Sold_items_A"],labels=df.iloc[:, 0] )

plt.xlabel("Year")
plt.ylabel("Sold_items_A")

# %%
plt.pie(df.loc[:,"Sold_items_A"],labels=df.iloc[:, 0] )
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# 21. Vamos a pintar un histograma

# %%
# Out:
#      Altura
# 0       187
# 1       162
# 2       158
# 3       159
# 4       161
# ..      ...
# 295     177
# 296     151
# 297     168
# 298     180
# 299     182
#
# [300 rows x 1 columns]

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
pd.DataFrame({"alturas":np.random.randn(1000)*12+170}).plot(kind="hist", bins=100)
# Out:
# <Axes: ylabel='Frequency'>
