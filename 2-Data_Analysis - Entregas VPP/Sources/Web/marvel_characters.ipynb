# %% [markdown]
# # Ataca la API de Marvel

# %% [markdown]
# Te tendrás que [registrar](https://developer.marvel.com/) y consultar la [documentación](https://developer.marvel.com/docs)

# %% [markdown]
# Queremos que consultes a la api para que te devuelva la info de los personajes de marvel que empiecen por la inicial de tu nombre. Tendríamos que generar un main.py (más los scripts que se te ocurran) que guarde un csv la información con la siguiente estructura
#
# ![imagen](./img/Captura_marvel.PNG)

# %% [markdown]
# Aquí te dejamos el código en python para poder empezar a hacer las llamadas, rellenando algunas variables como tus keys, parámetros de la llamada y la url (endpoint) a la que quieres acceder

# %%
import hashlib
import requests
import datetime
import pandas as pd

# %%
def hash_params():
    """ Marvel API requires server side API calls to include
    md5 hash of timestamp + public key + private key """

    hash_md5 = hashlib.md5()
    hash_md5.update(f'{timestamp}{priv_key}{pub_key}'.encode('utf-8'))
    hashed_params = hash_md5.hexdigest()

    return hashed_params

# %%
timestamp = datetime.datetime.now().strftime('%Y-%m-%d%H:%M:%S')

pub_key = 'dcfa67744d198a80776e92810ccdc2e0'
priv_key = '911ff403f58e6f8258d31e19892ce8d7b18c5578'

params = {'limit' : 100,
        'nameStartsWith': 'v',
        'ts': timestamp, 
        'apikey': pub_key, 
        'hash': hash_params()};

url = 'http://gateway.marvel.com/v1/public/characters'

res = requests.get(url,params=params)

# %%
res
# Out:
# <Response [200]>

# %%
r = requests.get(url,
                 params=params)

data= r.json()

# %%
data
# Out:
# {'code': 200,
#  'status': 'Ok',
#  'copyright': '© 2024 MARVEL',
#  'attributionText': 'Data provided by Marvel. © 2024 MARVEL',
#  'attributionHTML': '<a href="http://marvel.com">Data provided by Marvel. © 2024 MARVEL</a>',
#  'etag': '229e827d112b95d1ff9fba7840eaed463c6d2201',
#  'data': {'offset': 0,
#   'limit': 100,
#   'total': 33,
#   'count': 33,
#   'results': [{'id': 1009525,
#     'name': 'Valeria Richards',
#     'description': '',
#     'modified': '2012-03-02T10:26:15-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/60/4d541255f088a',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009525',
#     'comics': {'available': 82,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009525/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/39019',
#        'name': 'Amazing Spider-Man (1999) #658'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/38716',
#        'name': 'Amazing Spider-Man (1999) #658 (THOR HOLLYWOOD VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/39018',
#        'name': 'Amazing Spider-Man (1999) #659'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/35505',
#        'name': 'Amazing Spider-Man (1999) #660'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/112131',
#        'name': 'DOOM (2024) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/90816',
#        'name': 'Empyre: Fallout Fantastic Four  (2020) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/44927',
#        'name': 'Fantastic Four (2012) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46092',
#        'name': 'Fantastic Four (2012) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46094',
#        'name': 'Fantastic Four (2012) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46096',
#        'name': 'Fantastic Four (2012) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/47073',
#        'name': 'Fantastic Four (2012) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46098',
#        'name': 'Fantastic Four (2012) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46099',
#        'name': 'Fantastic Four (2012) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46100',
#        'name': 'Fantastic Four (2012) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46101',
#        'name': 'Fantastic Four (2012) #9'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68016',
#        'name': 'Fantastic Four (2018) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46102',
#        'name': 'Fantastic Four (2012) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46103',
#        'name': 'Fantastic Four (2012) #11'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46104',
#        'name': 'Fantastic Four (2012) #12'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/46105',
#        'name': 'Fantastic Four (2012) #13'}],
#      'returned': 20},
#     'series': {'available': 16,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009525/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/454',
#        'name': 'Amazing Spider-Man (1999 - 2013)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/38649',
#        'name': 'DOOM (2024 - Present)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/31223',
#        'name': 'Empyre: Fallout Fantastic Four  (2020)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/24554',
#        'name': 'Fantastic Four (2018 - Present)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/34035',
#        'name': 'Fantastic Four (2022 - Present)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/16557',
#        'name': 'Fantastic Four (2012 - 2014)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/421',
#        'name': 'Fantastic Four (1998 - 2012)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1265',
#        'name': 'FANTASTIC FOUR VOL. 1 HC (2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1266',
#        'name': 'Fantastic Four Vol. 2 (2005)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/232',
#        'name': 'FANTASTIC FOUR VOL. 2: UNTHINKABLE TPB (2003)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1659',
#        'name': 'Fantastic Four Vol. 3 (2005)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/28353',
#        'name': 'Fantastic Four: Road Trip  (2020)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/13440',
#        'name': 'FF (2011 - 2012)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/34009',
#        'name': 'Marvel Meow Infinity Comic (2022)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/16451',
#        'name': 'New Avengers (2013 - 2015)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/4886',
#        'name': 'Secret Invasion: Fantastic Four (2008)'}],
#      'returned': 16},
#     'stories': {'available': 89,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009525/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/802',
#        'name': 'Fantastic Four (1998) #509',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/803',
#        'name': 'Interior #803',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/912',
#        'name': 'Fantastic Four (1998) #512',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/913',
#        'name': 'Interior #913',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/918',
#        'name': 'Fantastic Four (1998) #514',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/919',
#        'name': 'Interior #919',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/920',
#        'name': 'Fantastic Four (1998) #517',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/921',
#        'name': 'Interior #921',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/922',
#        'name': 'Fantastic Four (1998) #518',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/923',
#        'name': 'AVENGERS DISASSEMBLED TIE-IN! "FOURTITUDE" PART 2 (OF 3) With public opinion of the FF at an all-time low and with all of Manhat',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/2793',
#        'name': 'Fantastic Four (1998) #510',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/2794',
#        'name': 'Interior #2794',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26087',
#        'name': 'interior to FF #500',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26088',
#        'name': 'interior to FF #501',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26089',
#        'name': 'interior to FF #502',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/31865',
#        'name': 'interior to FF (1998) #68',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/47580',
#        'name': 'SECRET INVASION: FANTASTIC FOUR (2008) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/52673',
#        'name': 'FANTASTIC FOUR (1998) #565',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/64348',
#        'name': 'FANTASTIC FOUR (1998) #580',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/64350',
#        'name': 'Fantastic Four (1998) #581',
#        'type': 'cover'}],
#      'returned': 20},
#     'events': {'available': 4,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009525/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/234',
#        'name': 'Avengers Disassembled'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/287',
#        'name': 'Heroic Age'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/319',
#        'name': 'Original Sin'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/269',
#        'name': 'Secret Invasion'}],
#      'returned': 4},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2755/amanda_sefton?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Richards%2C_Valeria?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009525/valeria_richards?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1017841,
#     'name': 'Valkyrie (Exiles)',
#     'description': '',
#     'modified': '2021-08-04T11:57:19-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1017841',
#     'comics': {'available': 12,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1017841/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/66769',
#        'name': 'Exiles (2018) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/66911',
#        'name': 'Exiles (2018) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/67337',
#        'name': 'Exiles (2018) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68356',
#        'name': 'Exiles (2018) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68358',
#        'name': 'Exiles (2018) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68360',
#        'name': 'Exiles (2018) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68361',
#        'name': 'Exiles (2018) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68362',
#        'name': 'Exiles (2018) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68363',
#        'name': 'Exiles (2018) #9'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68364',
#        'name': 'Exiles (2018) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68365',
#        'name': 'Exiles (2018) #11'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/68366',
#        'name': 'Exiles (2018) #12'}],
#      'returned': 12},
#     'series': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1017841/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/24155',
#        'name': 'Exiles (2018 - 2019)'}],
#      'returned': 1},
#     'stories': {'available': 12,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1017841/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/144693',
#        'name': 'cover from Exiles (2018) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/144977',
#        'name': 'cover from Exiles (2018) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/145860',
#        'name': 'cover from Exiles (2018) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149112',
#        'name': 'cover from Exiles (2018) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149116',
#        'name': 'cover from Exiles (2018) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149120',
#        'name': 'cover from Exiles (2018) #6',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149122',
#        'name': 'cover from Exiles (2018) #7',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149124',
#        'name': 'cover from Exiles (2018) #8',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149126',
#        'name': 'cover from Exiles (2018) #9',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149128',
#        'name': 'cover from Exiles (2018) #10',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149130',
#        'name': 'cover from Exiles (2018) #11',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/149132',
#        'name': 'cover from Exiles (2018) #12',
#        'type': 'cover'}],
#      'returned': 12},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1017841/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/62/valkyrie?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1017841/valkyrie_exiles?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1010350,
#     'name': 'Valkyrie (Samantha Parrington)',
#     'description': "Amora magically transformed Samantha Parrington into a raging, man-hating facsimile of the Asgardian warrior goddess Brunnhilde the Valkyrie, whose form and might Amora could replicate at will, having trapped Brunnhilde's soul in a mystical crystal centuries earlier.",
#     'modified': '2014-04-29T14:23:28-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/c/00/535fed8a3a00f',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1010350',
#     'comics': {'available': 17,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010350/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/7016',
#        'name': 'Avengers (1963) #157'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20355',
#        'name': 'Defenders (1972) #46'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20358',
#        'name': 'Defenders (1972) #49'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20360',
#        'name': 'Defenders (1972) #50'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20279',
#        'name': 'Defenders (1972) #114'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20190',
#        'name': 'Doctor Strange, Sorcerer Supreme (1988) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20201',
#        'name': 'Doctor Strange, Sorcerer Supreme (1988) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20026',
#        'name': 'Giant-Size Defenders (1974) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/39890',
#        'name': 'Heralds (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/10086',
#        'name': 'Marvel Comics Presents (1988) #168'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15504',
#        'name': 'Marvel Super-Heroes (1967) #93'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/29091',
#        'name': 'Secret Avengers (2010) #11'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30253',
#        'name': 'Valkyrie (2010) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/23490',
#        'name': 'Warlock Chronicles (1993) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/12369',
#        'name': 'X-Men Annual (1970) #9'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/1152',
#        'name': 'X-Men Legends Vol. 3: Art Adams Book I (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/1185',
#        'name': 'X-Men Legends Vol. III: Arthur Adams Book I (Trade Paperback)'}],
#      'returned': 17},
#     'series': {'available': 14,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010350/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/1991',
#        'name': 'Avengers (1963 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3743',
#        'name': 'Defenders (1972 - 1986)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3741',
#        'name': 'Doctor Strange, Sorcerer Supreme (1988 - 1996)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3731',
#        'name': 'Giant-Size Defenders (1974)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/13065',
#        'name': 'Heralds (2010)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2039',
#        'name': 'Marvel Comics Presents (1988 - 1995)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2300',
#        'name': 'Marvel Super-Heroes (1967 - 1982)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/9799',
#        'name': 'Secret Avengers (2010 - 2012)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/886',
#        'name': 'She-Hulk (2005 - 2009)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/9973',
#        'name': 'Valkyrie (2010)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/6686',
#        'name': 'Warlock Chronicles (1993 - 1994)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2100',
#        'name': 'X-Men Annual (1970 - 1994)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/211',
#        'name': 'X-Men Legends Vol. 3: Art Adams Book I (2003)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/242',
#        'name': 'X-Men Legends Vol. III: Arthur Adams Book I (2003)'}],
#      'returned': 14},
#     'stories': {'available': 18,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010350/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/14570',
#        'name': 'A Ghost of Stone!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/19885',
#        'name': "There's No Place Like Home",
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/23122',
#        'name': 'Freedom',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/26205',
#        'name': 'Cover #26205',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/31554',
#        'name': "They Shoot Hulks, Don't They?",
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/42884',
#        'name': 'The Dynamic Defenders!',
#        'type': 'pinup'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43255',
#        'name': 'PanDEMONium',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43256',
#        'name': 'Dragoncircle',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43281',
#        'name': "Dragon's Dream",
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43458',
#        'name': 'Dance of Darkness/Dance of Light!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43611',
#        'name': '[Who Remembers Scorpio?!*]',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43612',
#        'name': 'Who Remembers Scorpio?',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43619',
#        'name': 'Cover to Defenders #49',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/43624',
#        'name': 'Cover to Defenders #50',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/52071',
#        'name': 'Reunion',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/69333',
#        'name': 'Interior #69333',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/76409',
#        'name': 'SECRET AVENGERS 11',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/90548',
#        'name': 'Heralds TPB',
#        'type': 'cover'}],
#      'returned': 18},
#     'events': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010350/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/235',
#        'name': 'Blood and Thunder'}],
#      'returned': 1},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/62/valkyrie?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Valkyrie_(Samantha_Parrington)?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1010350/valkyrie_samantha_parrington?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1011239,
#     'name': 'Valkyrie (Ultimate)',
#     'description': '',
#     'modified': '2014-03-05T13:58:33-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/4/20/53177396dc74f',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011239',
#     'comics': {'available': 9,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011239/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30600',
#        'name': 'Ultimate Comics New Ultimates (2010) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30602',
#        'name': 'Ultimate Comics New Ultimates (2010) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17378',
#        'name': 'Ultimates 3 (2007) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17617',
#        'name': 'Ultimates 3 (2007) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17618',
#        'name': 'Ultimates 3 (2007) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20663',
#        'name': 'Ultimates 3 (2007) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/20818',
#        'name': 'Ultimates 3 (2007) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/26923',
#        'name': 'Ultimates 3 (2007) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/24316',
#        'name': 'Ultimates 3: Who Killed the Scarlet Witch? (Trade Paperback)'}],
#      'returned': 9},
#     'series': {'available': 3,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011239/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/9026',
#        'name': 'Ultimate Comics New Ultimates (2010 - 2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3188',
#        'name': 'Ultimates 3 (2007 - 2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/7515',
#        'name': 'Ultimates 3: Who Killed the Scarlet Witch? (2009 - Present)'}],
#      'returned': 3},
#     'stories': {'available': 14,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011239/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36430',
#        'name': 'Ultimates 3 (2007) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36431',
#        'name': 'Sex, Lies, and DVDs 1 of 5',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36864',
#        'name': 'Ultimates 3 (2007) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36865',
#        'name': 'Sex, Lies, and DVDs 2 of 5',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36866',
#        'name': 'Ultimates 3 (2007) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36867',
#        'name': 'Sex, Lies, and DVDs 2 of 5',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/44308',
#        'name': 'Ultimates 3 (2007) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/44309',
#        'name': 'Sex, Lies, and DVDs 3 of 5',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/44588',
#        'name': 'Ultimates 3 (2007) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/44589',
#        'name': 'Interior #44589',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/59157',
#        'name': 'Ultimates 3 (2007) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/59158',
#        'name': 'Interior #59158',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/70026',
#        'name': 'Cover #70026',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/70030',
#        'name': 'Cover #70030',
#        'type': 'cover'}],
#      'returned': 14},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011239/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/62/valkyrie?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Valkyrie%20(Ultimate)?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011239/valkyrie_ultimate?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1011182,
#     'name': 'Vampiro',
#     'description': 'Vampiro, part of the race known as the Eternals, lived on Earth for many years, eventually taking a wife and making a career for himself as a professional wrestler.',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/8/b0/4c002f27b9a1e',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011182',
#     'comics': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011182/comics',
#      'items': [],
#      'returned': 0},
#     'series': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011182/series',
#      'items': [],
#      'returned': 0},
#     'stories': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011182/stories',
#      'items': [],
#      'returned': 0},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011182/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2464/vampiro?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vampiro?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011182/vampiro?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1011342,
#     'name': 'Vance Astro',
#     'description': '',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011342',
#     'comics': {'available': 38,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011342/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50965',
#        'name': 'Guardians 3000 (2014) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51057',
#        'name': 'Guardians 3000 (2014) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51868',
#        'name': 'Guardians 3000 (2014) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51870',
#        'name': 'Guardians 3000 (2014) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51872',
#        'name': 'Guardians 3000 (2014) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51874',
#        'name': 'Guardians 3000 (2014) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/51875',
#        'name': 'Guardians 3000 (2014) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50817',
#        'name': 'Guardians of the Galaxy (1990) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50818',
#        'name': 'Guardians of the Galaxy (1990) #2'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50819',
#        'name': 'Guardians of the Galaxy (1990) #3'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50820',
#        'name': 'Guardians of the Galaxy (1990) #4'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50821',
#        'name': 'Guardians of the Galaxy (1990) #5'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50822',
#        'name': 'Guardians of the Galaxy (1990) #6'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50823',
#        'name': 'Guardians of the Galaxy (1990) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50863',
#        'name': 'Guardians of the Galaxy (1990) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50865',
#        'name': 'Guardians of the Galaxy (1990) #9'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50864',
#        'name': 'Guardians of the Galaxy (1990) #10'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50866',
#        'name': 'Guardians of the Galaxy (1990) #11'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50867',
#        'name': 'Guardians of the Galaxy (1990) #12'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/50868',
#        'name': 'Guardians of the Galaxy (1990) #13'}],
#      'returned': 20},
#     'series': {'available': 4,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011342/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/19434',
#        'name': 'Guardians 3000 (2014 - 2015)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/19019',
#        'name': 'Guardians of the Galaxy (1990 - 1994)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/19020',
#        'name': 'Guardians of the Galaxy Annual (1991)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3715',
#        'name': 'Marvel Two-in-One (1974 - 1983)'}],
#      'returned': 4},
#     'stories': {'available': 59,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011342/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/41443',
#        'name': 'Homecoming!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/113820',
#        'name': 'Guardians 3000 #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/113904',
#        'name': 'Guardians 3000 (2014) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/115313',
#        'name': 'cover from Guardians 3000 (2014) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/115317',
#        'name': 'cover from Guardians 3000 (2014) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/115321',
#        'name': 'cover from Guardians 3000 (2014) #6',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/115325',
#        'name': 'cover from Guardians 3000 (2014) #7',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/115327',
#        'name': 'cover from Guardians 3000 (2014) #8',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130418',
#        'name': 'Guardians of the Galaxy Annual (1991)',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130419',
#        'name': 'interior to Guardians of the Galaxy Annual (1991)',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130494',
#        'name': 'Guardians of the Galaxy (1990) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130495',
#        'name': 'interior to Guardians of the Galaxy (1990) #1',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130496',
#        'name': 'Guardians of the Galaxy (1990) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130497',
#        'name': 'interior to Guardians of the Galaxy (1990) #2',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130498',
#        'name': 'Guardians of the Galaxy (1990) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130499',
#        'name': 'interior to Guardians of the Galaxy (1990) #3',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130500',
#        'name': 'Guardians of the Galaxy (1990) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130501',
#        'name': 'interior to Guardians of the Galaxy (1990) #4',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130502',
#        'name': 'Guardians of the Galaxy (1990) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/130503',
#        'name': 'interior to Guardians of the Galaxy (1990) #5',
#        'type': 'interiorStory'}],
#      'returned': 20},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011342/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2918/vance_astro?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Astro,_Vance_(Major_Victory)?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011342/vance_astro?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1010989,
#     'name': 'Vanisher (Age of Apocalypse)',
#     'description': 'Vanisher worked for Apocalypse.',
#     'modified': '2013-10-18T16:35:15-0400',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1010989',
#     'comics': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010989/comics',
#      'items': [],
#      'returned': 0},
#     'series': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010989/series',
#      'items': [],
#      'returned': 0},
#     'stories': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010989/stories',
#      'items': [],
#      'returned': 0},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010989/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2466/vanisher?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vanisher_(Age_of_Apocalypse)?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1010989/vanisher_age_of_apocalypse?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1011365,
#     'name': 'Vanisher (Telford Porter)',
#     'description': "Nothing is known about the Vanisher's past before he embarked on a one-man crime wave of spectacular thefts using his power of self-teleportation.",
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011365',
#     'comics': {'available': 12,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011365/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/23971',
#        'name': 'Cable (2008) #13'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/23972',
#        'name': 'Cable (2008) #13 (MW, 50/50 Variant)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/24171',
#        'name': 'Cable (2008) #14'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/24172',
#        'name': 'Cable (2008) #14 (MW, 50/50 Variant)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/24631',
#        'name': 'Cable (2008) #15'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/24632',
#        'name': 'Cable (2008) #15 (MW, 50/50 Variant)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/13156',
#        'name': 'Fantastic Four (1961) #335'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/12539',
#        'name': 'Uncanny X-Men (1963) #86'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/21996',
#        'name': 'X-Force (2008) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22322',
#        'name': 'X-Force (2008) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/22521',
#        'name': 'X-Force (2008) #9'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/12466',
#        'name': 'Uncanny X-Men (1963) #2'}],
#      'returned': 12},
#     'series': {'available': 4,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011365/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/4002',
#        'name': 'Cable (2008 - 2010)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2121',
#        'name': 'Fantastic Four (1961 - 1998)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2258',
#        'name': 'Uncanny X-Men (1963 - 2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/3839',
#        'name': 'X-Force (2008 - 2010)'}],
#      'returned': 4},
#     'stories': {'available': 13,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011365/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/12962',
#        'name': 'Fantastic Four (1961) #335',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/15483',
#        'name': 'Uncanny X-Men (1963) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/15663',
#        'name': 'Cover #15663',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/48438',
#        'name': '1 of 4',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/49147',
#        'name': 'X-Force (2008) #8',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/49148',
#        'name': '2 of 4',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/49923',
#        'name': 'Old Ghosts 3 of 4',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53172',
#        'name': 'Cable (2008) #13 - Int',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53174',
#        'name': 'Cable (2008) #13, 50/50 Variant - Int',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53567',
#        'name': 'Cable (2008) #14 - Int',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/53569',
#        'name': 'Cable (2008) #14, 50/50 Variant - Int',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/54491',
#        'name': 'Cable (2008) #15 - Int',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/54493',
#        'name': 'Cable (2008) #15, 50/50 Variant - Int',
#        'type': 'interiorStory'}],
#      'returned': 13},
#     'events': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011365/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/116',
#        'name': 'Acts of Vengeance!'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/events/298',
#        'name': 'Messiah War'}],
#      'returned': 2},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2466/vanisher?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vanisher%20(Telford%20Porter)?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011365/vanisher_telford_porter?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1009689,
#     'name': 'Vanisher (Ultimate)',
#     'description': 'Vanisher is a mutant with the power to teleport himself and possibly others across an undefined amount of distance who was recruited by Magneto into his Brotherhood of Mutants.',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009689',
#     'comics': {'available': 3,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009689/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/18474',
#        'name': 'Ultimate War (2003) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/1158',
#        'name': 'ULTIMATE X-MEN VOL. 5: ULTIMATE WAR TPB (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/13949',
#        'name': 'Uncanny X-Men (1963) #408'}],
#      'returned': 3},
#     'series': {'available': 3,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009689/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/3659',
#        'name': 'Ultimate War (2003)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/216',
#        'name': 'ULTIMATE X-MEN VOL. 5: ULTIMATE WAR TPB (1999)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2258',
#        'name': 'Uncanny X-Men (1963 - 2011)'}],
#      'returned': 3},
#     'stories': {'available': 2,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009689/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/28365',
#        'name': 'Identity Crisis',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/39348',
#        'name': 'Interior #39348',
#        'type': 'interiorStory'}],
#      'returned': 2},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009689/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2466/vanisher?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vanisher_%28Ultimate%29?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009689/vanisher_ultimate?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1011316,
#     'name': 'Vapor',
#     'description': 'Vapor, along with her brother, was among the small group led by Simon Utrecht to simulate the crash that gave the Fantastic Four their powers, and has remained with the U-Foes ever since.',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/40/4c002e541867f',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1011316',
#     'comics': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011316/comics',
#      'items': [],
#      'returned': 0},
#     'series': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011316/series',
#      'items': [],
#      'returned': 0},
#     'stories': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011316/stories',
#      'items': [],
#      'returned': 0},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011316/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2469/vapor?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vapor?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011316/vapor?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1009690,
#     'name': 'Vargas',
#     'description': 'Vargas claimed that mutants are deviations from the norm, an evolutionary dead end nature explored until it found the true path for the next step in mutant kinds development, the legitimate Homo Sapiens Superior, namely, himself.',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/8/80/4c003a81cef50',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009690',
#     'comics': {'available': 15,
# ...
#        'name': 'X-Men: Deadly Genesis (2005 - 2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1545',
#        'name': 'X-MEN: DEADLY GENESIS TPB (2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2837',
#        'name': 'X-Men: Emperor Vulcan (2007 - 2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/4513',
#        'name': 'X-Men: Emperor Vulcan (2008)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/6418',
#        'name': 'X-Men: Kingbreaker (2008 - 2009)'}],
#      'returned': 11},
#     'stories': {'available': 22,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011011/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/471',
#        'name': 'Cover #471',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/776',
#        'name': 'UNCANNY X-MEN (1963) #475',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/785',
#        'name': 'UNCANNY X-MEN (1963) #480',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/787',
#        'name': 'UNCANNY X-MEN (1963) #481',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/7611',
#        'name': 'UNCANNY X-MEN (1963) #484',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/8077',
#        'name': 'UNCANNY X-MEN (1963) #485',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/8570',
#        'name': 'UNCANNY X-MEN (1963) #486',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/33359',
#        'name': 'X-MEN: EMPEROR VULCAN (2007) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/36905',
#        'name': 'X-MEN: EMPEROR VULCAN (2007) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/51056',
#        'name': '4XLS 1 of 4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/51402',
#        'name': '4XLS 2 of 4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/52400',
#        'name': '4XLS 3 of 4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/52882',
#        'name': '4XLS 4 of 4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/66089',
#        'name': 'UNCANNY X-MEN (1963) #483',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/132244',
#        'name': 'story from War of Kings Prelude: Road to War of Kings (2017)',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/157447',
#        'name': 'cover from Black Goliath (1976) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/176963',
#        'name': 'cover from X-Men (2019) #9',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/176965',
#        'name': 'cover from X-Men (2019) #10',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/213595',
#        'name': 'cover from X-Men: Red (2022) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/213597',
#        'name': 'cover from X-Men: Red (2022) #2',
#        'type': 'cover'}],
#      'returned': 20},
#     'events': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1011011/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/276',
#        'name': 'War of Kings'}],
#      'returned': 1},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/comics/characters/1011011/vulcan_gabriel_summers?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vulcan_%28Gabriel_Summers%29?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1011011/vulcan_gabriel_summers?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1009699,
#     'name': 'Vulture (Adrian Toomes)',
#     'description': 'Adrian Toomes is a former electronics engineer who employs a special harness of his own design that allows him to fly and endows him with enhanced strength.',
#     'modified': '2017-01-31T11:10:36-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/50/4c003a7929d28',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009699',
#     'comics': {'available': 104,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009699/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/60151',
#        'name': 'A YEAR OF MARVELS TPB (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/57924',
#        'name': 'A Year of Marvels: February Infinite Comic (2016) #1'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/6811',
#        'name': 'The Amazing Spider-Man (1963) #396'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30298',
#        'name': 'Amazing Spider-Man (1999) #623'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/31465',
#        'name': 'Amazing Spider-Man (1999) #623 (VILLAIN VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/31466',
#        'name': 'Amazing Spider-Man (1999) #623 (JUSKO VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30299',
#        'name': 'Amazing Spider-Man (1999) #624'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/33540',
#        'name': "Amazing Spider-Man (1999) #624 (YOU'RE FIRED VARIANT)"},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/32537',
#        'name': 'Amazing Spider-Man (1999) #634 (50/50 VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/37039',
#        'name': 'Amazing Spider-Man (1999) #634 (2ND PRINTING VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30319',
#        'name': 'Amazing Spider-Man (1999) #644'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/35878',
#        'name': 'Amazing Spider-Man (1999) #645 (SPIDEY VS. VARIANT)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/34135',
#        'name': 'Amazing Spider-Man (1999) #648'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/35511',
#        'name': 'Amazing Spider-Man (1999) #674'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/15675',
#        'name': 'Daredevil (1998) #7'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/8213',
#        'name': 'Daredevil (1964) #225'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/953',
#        'name': 'DAREDEVIL VISIONARIES: KEVIN SMITH TPB (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/959',
#        'name': 'Daredevil: Love Labors Lost (Trade Paperback)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/8558',
#        'name': 'Earth X (1999) #8'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/comics/8559',
#        'name': 'Earth X (1999) #9'}],
#      'returned': 20},
#     'series': {'available': 49,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009699/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/22102',
#        'name': 'A YEAR OF MARVELS TPB (2017)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/25677',
#        'name': 'A Year of Marvels: February Infinite Comic (2016)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/454',
#        'name': 'Amazing Spider-Man (1999 - 2013)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/449',
#        'name': 'Daredevil (1998 - 2011)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2002',
#        'name': 'Daredevil (1964 - 1998)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/18',
#        'name': 'DAREDEVIL VISIONARIES: KEVIN SMITH TPB (1999)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/24',
#        'name': 'Daredevil: Love Labors Lost (1999)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/378',
#        'name': 'Earth X (1999 - 2000)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1806',
#        'name': 'EARTH X TPB [NEW PRINTING] (2006)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/37518',
#        'name': 'Edge of Venomverse Unlimited Infinity Comic (2023)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1427',
#        'name': 'ESSENTIAL PETER PARKER, THE SPECTACULAR SPIDER-MAN (2005)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/877',
#        'name': 'Friendly Neighborhood Spider-Man (2005 - 2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1895',
#        'name': 'Friendly Neighborhood Spider-Man Vol. 2: Mystery Date (2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/782',
#        'name': 'Identity Disc (2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1333',
#        'name': 'IDENTITY DISC TPB (2004)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/24197',
#        'name': 'Lethal Foes of Spider-Man (1993)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1102',
#        'name': 'Marvel 1602: Fantastick Four (2006 - 2007)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/1389',
#        'name': 'MARVEL MASTERWORKS: THE AMAZING SPIDER-MAN VOL. 7 HC (2005)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/22334',
#        'name': 'Marvel Masterworks: The Spectacular Spider-Man Vol. 1 (2017)'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/series/2301',
#        'name': 'Marvel Super Heroes (1990 - 1993)'}],
#      'returned': 20},
#     'stories': {'available': 111,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009699/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3794',
#        'name': 'IDENTITY DISC (2004) #3',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3796',
#        'name': 'IDENTITY DISC (2004) #2',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3798',
#        'name': 'IDENTITY DISC (2004) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3800',
#        'name': 'IDENTITY DISC (2004) #4',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/3802',
#        'name': 'IDENTITY DISC (2004) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/4662',
#        'name': 'Friendly Neighborhood Spider-Man (2005) #5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/4663',
#        'name': '1 of 1 -',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/4674',
#        'name': '1 of 5',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/4682',
#        'name': '2 of 3 - Vulture/Deb Whit',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/6053',
#        'name': 'Marvel 1602: Fantastick Four (2006) #1',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13538',
#        'name': 'The Spider Or The Man?',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13600',
#        'name': 'Cover #13600',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13602',
#        'name': 'Cover #13602',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13603',
#        'name': 'The Vulture Hangs High!',
#        'type': 'interiorStory'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13653',
#        'name': 'Cover #13653',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13824',
#        'name': 'Cover #13824',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13862',
#        'name': 'Wings of Vengeance',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/13864',
#        'name': 'In the Beginning',
#        'type': ''},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/14213',
#        'name': 'Cover #14213',
#        'type': 'cover'},
#       {'resourceURI': 'http://gateway.marvel.com/v1/public/stories/14217',
#        'name': 'Cover #14217',
#        'type': 'cover'}],
#      'returned': 20},
#     'events': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009699/events',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/events/116',
#        'name': 'Acts of Vengeance!'}],
#      'returned': 1},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2510/vulture?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vulture_%28Adrian_Toomes%29?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1009699/vulture_adrian_toomes?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]},
#    {'id': 1010990,
#     'name': 'Vulture (Blackie Drago)',
#     'description': 'Adrian Toomes, the Vulture, told his cellmate, Blackie Drago, the location of his Vulture costume.',
#     'modified': '1969-12-31T19:00:00-0500',
#     'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/5/50/4c00329c0dc23',
#      'extension': 'jpg'},
#     'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1010990',
#     'comics': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010990/comics',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/comics/62857',
#        'name': 'Spider-Man Vs. The Vulture (Trade Paperback)'}],
#      'returned': 1},
#     'series': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010990/series',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/series/23055',
#        'name': 'Spider-Man Vs. The Vulture (2017)'}],
#      'returned': 1},
#     'stories': {'available': 1,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010990/stories',
#      'items': [{'resourceURI': 'http://gateway.marvel.com/v1/public/stories/139361',
#        'name': 'Spider-Man Vs. The Vulture (2017)',
#        'type': 'cover'}],
#      'returned': 1},
#     'events': {'available': 0,
#      'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1010990/events',
#      'items': [],
#      'returned': 0},
#     'urls': [{'type': 'detail',
#       'url': 'http://marvel.com/characters/2510/vulture?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'wiki',
#       'url': 'http://marvel.com/universe/Vulture_%28Blackie_Drago%29?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'},
#      {'type': 'comiclink',
#       'url': 'http://marvel.com/comics/characters/1010990/vulture_blackie_drago?utm_campaign=apiRef&utm_source=dcfa67744d198a80776e92810ccdc2e0'}]}]}}

# %%
data["data"]["results"][0]["thumbnail"]
# Out:
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/60/4d541255f088a',
#  'extension': 'jpg'}

# %%
data["data"]["results"][0]["id"]
# Out:
# 1009525

# %%
data["data"]["results"][0]["name"]
# Out:
# 'Valeria Richards'

# %%
for i, cosa in enumerate (data["data"]["results"][0]):
    print(data["data"]["results"][i]["id"])
    print(data["data"]["results"][i]["name"])
    print(data["data"]["results"][i]["thumbnail"])
# Out:
# 1009525
# Valeria Richards
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/60/4d541255f088a', 'extension': 'jpg'}
# 1017841
# Valkyrie (Exiles)
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available', 'extension': 'jpg'}
# 1010350
# Valkyrie (Samantha Parrington)
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/c/00/535fed8a3a00f', 'extension': 'jpg'}
# 1011239
# Valkyrie (Ultimate)
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/4/20/53177396dc74f', 'extension': 'jpg'}
# 1011182
# Vampiro
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/8/b0/4c002f27b9a1e', 'extension': 'jpg'}
# 1011342
# Vance Astro
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available', 'extension': 'jpg'}
# 1010989
# Vanisher (Age of Apocalypse)
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available', 'extension': 'jpg'}
# 1011365
# Vanisher (Telford Porter)
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available', 'extension': 'jpg'}
# 1009689
# Vanisher (Ultimate)
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/b/40/image_not_available', 'extension': 'jpg'}
# 1011316
# Vapor
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/40/4c002e541867f', 'extension': 'jpg'}
# 1009690
# Vargas
# {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/8/80/4c003a81cef50', 'extension': 'jpg'}

# %%
id = []
name = []
picture_url = []

for i, cosa in enumerate (data["data"]["results"][0]):
    id.append((data["data"]["results"][i]["id"]))
    name.append(data["data"]["results"][i]["name"])
    picture_url.append(data["data"]["results"][i]["thumbnail"])

df = pd.DataFrame({
                    "Id":id,
                    "Name": name,
                    "Picture URL": picture_url
                    })
df
# Out:
#          Id                            Name  \
# 0   1009525                Valeria Richards
# 1   1017841               Valkyrie (Exiles)
# 2   1010350  Valkyrie (Samantha Parrington)
# 3   1011239             Valkyrie (Ultimate)
# 4   1011182                         Vampiro
# 5   1011342                     Vance Astro
# 6   1010989    Vanisher (Age of Apocalypse)
# 7   1011365       Vanisher (Telford Porter)
# 8   1009689             Vanisher (Ultimate)
# 9   1011316                           Vapor
# 10  1009690                          Vargas
#
#                                           Picture URL
# 0   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 1   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 2   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 3   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 4   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 5   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 6   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 7   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 8   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 9   {'path': 'http://i.annihil.us/u/prod/marvel/i/...
# 10  {'path': 'http://i.annihil.us/u/prod/marvel/i/...
